# %%
"""
Written by: Tommy Banker (thomas_banker@berkeley.edu)
"""

import os
import json
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt
from utils import *




matplotlib.rcParams.update({# Use mathtext, not LaTeX
                            'text.usetex': False,
                            # Use the Computer modern font
                            'font.family': 'serif',
                            'font.serif': 'cmr10',
                            'mathtext.fontset': 'cm',
                            # Use ASCII minus
                            'axes.unicode_minus': False,
                            'figure.dpi' : 300,

                            })

font = {'weight' : 'bold',
        'size'   : 34}
plt.rc('font', **font)

# %%
df = pd.read_csv('../prop_data/MORDRED_SMILES_cep_PCE.csv')
print('y1',df['y1'].max(),df['y1'].min())
print('y2',df['y2'].max(),df['y2'].min())
print((df['y1'].max()-df['y1'].min())*df['y2'].max())
print((df['y1'].min()-df['y1'].min())*df['y2'].min())
# Out:
# y1 11.086613 -6.9454
# y2 6.28264746528153 1.52136277607866
# 113.28878076837358
# 0.0

# %%
y2__  = df['y2']*-1


best = -1*(df['y1'].max()-df['y1'].min())*( df['y2'].max()*-1 +df['y2'].max())
worst = -1*(df['y1'].min())*( df['y2'].max()*-1 +df['y2'].min())

best = best-worst

print(best, worst)
# Out:
# 33.06902668038961 -33.06902668038961

# %%
methods = ['cep', ]
best = -1*(df['y1'].max()-df['y1'].min())*( df['y2'].max()*-1 +df['y2'].max())
best_list = {'cep': best}

seeds = [0,1,2,3,4,]

# %%
sample_configs = [r'./config/cep_multiobjective/CEP_SAAS_0.json',
                 r'./config/cep_multiobjective/CEP_GP_full_0.json',
                 r'./config/cep_multiobjective/CEP_GP_pca_0.json',
                 r'./config/cep_multiobjective/CEP_Random_0.json']

names = ['SAAS','GP_full','GP_PCA' ,'random']
names2 = ['MolDAIS','SGP',"SGP-PCA", 'Random']

Res_dict_raw = {'SAAS':[], 'GP_full':[],'GP_PCA':[], 'random':[]}        
Res_dict_stat = {'SAAS':[], 'GP_full':[],'GP_PCA':[], 'random':[]}               
Smi_dict_stat = {'SAAS':[], 'GP_full':[],'GP_PCA':[], 'random':[]}         

for i100,sample_config in enumerate(sample_configs):        
    with open(sample_config) as f:
        exp_config = json.load(f)
    ########    
    y_variable = 'cep'#exp_config['common']['y_variable']
    max_min = exp_config['common']['max_min']
    init_budget = exp_config['common']['init_budget']
    total_budget = 100#exp_config['common']['total_budget']
    bo_iters = np.arange(1, total_budget - init_budget + 1)
    ########
    all_results = np.zeros((len(methods), len(seeds), total_budget))
    smi_results = []
    sorted_results = np.zeros((len(methods), len(seeds), total_budget - init_budget + 1))
    conv_results = np.zeros((len(methods), (total_budget - init_budget + 1), 2))
    ########
    for i, method in enumerate(methods):
        for j, seed in enumerate(seeds):
            exp_config['exp_name'] = method #+ '_' + str(seed) 
            exp_config['seed'] = seed
            path = os.path.join('../results/', 'cep',)
            
            if i100 == 10 : 
                filename = get_filename(bo_iters[-1], exp_config).replace('logp', 'cep')#.replace('SAASGP','Multi-Output-SAAS')
            else :
                filename = get_filename(bo_iters[-1], exp_config).replace('logp', 'cep')#.replace('GP','Multi-Output-GP')
            print(filename)
            try: 
                result = torch.load(os.path.join(path, filename + '.pkl'))
                all_results[i,j,:] = -1*(6.9454+result['y_train'][:,0])*(result['y_train'][:,1]+df['y2'].max()) - worst
            except: 
                result = torch.load(os.path.join(path, filename.replace('None_seed_','None_q_1_seed_') + '.pkl'))
                all_results[i,j,:] = -1*(6.9454+result['y_train'][:-1,0])*(result['y_train'][:-1,1] +df['y2'].max())-worst
            
            #if sum( all_results[i,j,:]<0)>0: 
            #    print(method, seed, result['y_train'][:,0],result['y_train'][:,1]*(-1))
            smi_results.append( result['smiles_train'])
    ########
    sorted_results[:,:,0] = np.max(all_results[:,:,:init_budget], axis=2)
    print()
    for i, method in enumerate(methods):
        for j, seed in enumerate(seeds):
            for sample in np.arange(total_budget - init_budget):
                if all_results[i,j,(init_budget + sample)] > sorted_results[i,j,sample]:
                    sorted_results[i,j,(sample + 1)] = all_results[i,j,(init_budget + sample)]
                else:
                    sorted_results[i,j,(sample + 1)] = sorted_results[i,j,(sample)]
    ########
    for i, method in enumerate(methods):
        for sample in np.arange(total_budget - init_budget + 1):
            conv_results[i,sample,0] = np.mean(sorted_results[i,:,sample])
            conv_results[i,sample,1] = np.std(sorted_results[i,:,sample])
    ########
    sample_numbers = np.arange(total_budget - init_budget + 1)
    #max_min_vars = torch.load('../prop_data/max_min_vars.pkl')
    '''if max_min == 'max':
        conv_results[:,:,0] = (conv_results[:,:,0] )#*-1 + best #- max_min_vars[y_variable]['max']) * -1
    else:   # convention appears strange bc results as stored are already the
            # negative of the true values to perform minimization experiments
        conv_results[:,:,0] = (conv_results[:,:,0] - -1 * max_min_vars[y_variable]['min']) * -1
    '''
    
    Res_dict_raw[names[i100]] = sorted_results
    Res_dict_stat[names[i100]] = conv_results    
    Smi_dict_stat[names[i100]] = smi_results
# Out:
# cep_max_y1_Multi-Output-SAAS_q_1_seed_0_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-SAAS_q_1_seed_1_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-SAAS_q_1_seed_2_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-SAAS_q_1_seed_3_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-SAAS_q_1_seed_4_bo-iter_90_10_to_100_samples_EHVI_None_None
#
# cep_max_y1_Multi-Output-GP_q_1_seed_0_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-GP_q_1_seed_1_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-GP_q_1_seed_2_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-GP_q_1_seed_3_bo-iter_90_10_to_100_samples_EHVI_None_None
# cep_max_y1_Multi-Output-GP_q_1_seed_4_bo-iter_90_10_to_100_samples_EHVI_None_None
#
# cep_max_y1_Multi-Output-GP_q_1_seed_0_bo-iter_90_10_to_100_samples_EHVI_pca_6
# cep_max_y1_Multi-Output-GP_q_1_seed_1_bo-iter_90_10_to_100_samples_EHVI_pca_6
# cep_max_y1_Multi-Output-GP_q_1_seed_2_bo-iter_90_10_to_100_samples_EHVI_pca_6
# cep_max_y1_Multi-Output-GP_q_1_seed_3_bo-iter_90_10_to_100_samples_EHVI_pca_6
# cep_max_y1_Multi-Output-GP_q_1_seed_4_bo-iter_90_10_to_100_samples_EHVI_pca_6
#
# cep_max_y1_None_q_1_seed_0_bo-iter_90_10_to_100_samples_randomHV_None_None
# cep_max_y1_None_q_1_seed_1_bo-iter_90_10_to_100_samples_randomHV_None_None
# cep_max_y1_None_q_1_seed_2_bo-iter_90_10_to_100_samples_randomHV_None_None
# cep_max_y1_None_q_1_seed_3_bo-iter_90_10_to_100_samples_randomHV_None_None
# cep_max_y1_None_q_1_seed_4_bo-iter_90_10_to_100_samples_randomHV_None_None

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#01015c','#0302FC', ] 
end = 0

fig = plt.figure(figsize=(12,9))
for i, method in enumerate(names):
    style = '-'
    conv_results = Res_dict_stat[method]
    plt.plot(sample_numbers, conv_results[0,:,0], style, linewidth=3, label=names2[i], c=colors[i])
    plt.fill_between(sample_numbers, conv_results[0,:,0]-(1.95*conv_results[0,:,1]/(len(seeds)**0.5)), conv_results[0,:,0]+(1.95*conv_results[0,:,1]/(len(seeds)**0.5)), alpha=0.25, color=colors[i])
plt.plot([0,90+end],[best,best],'k:')
plt.legend(loc=0)
#plt.title('Convergence Results Across ' + str(len(seeds)) + ' Runs with ' + str(init_budget) + ' Initial Random Samples')
plt.xlabel('Iterations')
plt.ylabel('Hyper Volume' )
#plt.yscale('log')
plt.xlim(0,90)    
#plt.ylim(0,3.5)    
plt.savefig('./figs/cep/Convergence_HV.png')
    

fig = plt.figure(figsize=(12,9))
for i, method in enumerate(names):
    for k in range(5):
        style = '-'
        conv_results = Res_dict_stat[method]
        plt.plot(sample_numbers, Res_dict_raw[method][0,k,:], style, linewidth=3, label=names2[i], c=colors[i], alpha=.5)
        #plt.fill_between(sample_numbers, conv_results[0,:,0]-(1.95*conv_results[0,:,1]/(len(seeds)**0.5)), conv_results[0,:,0]+(1.95*conv_results[0,:,1]/(len(seeds)**0.5)), alpha=0.1, color=colors[i])
plt.plot([0,90+end],[best,best],'k:')
#plt.legend(loc=0)
#plt.title('Convergence Results Across ' + str(len(seeds)) + ' Runs with ' + str(init_budget) + ' Initial Random Samples')
plt.xlabel('Iterations')
plt.ylabel('Hyper Volume' )
#plt.yscale('log')
plt.xlim(0,90)    
#plt.ylim(0,3.5)    
plt.savefig('./figs/cep/Convergence_log_HV.png')



'''    
#sorted_results
fig = plt.figure(figsize=(12,9))
for i, method in enumerate(names):
    
    style = '-'
    sorted_results = Res_dict_raw[method]
    plt.plot(sample_numbers, -1*sorted_results.squeeze(0).T+best, style, linewidth=3, label=method, c=colors[i])
    #plt.fill_between(sample_numbers, conv_results[i,:,0]-(1.95*conv_results[i,:,1]/(len(seeds)**0.5)), conv_results[i,:,0]+(1.95*conv_results[i,:,1]/(len(seeds)**0.5)), alpha=0.1, color=colors[i])
    #plt.title('Convergence Results Across ' + str(len(seeds)) + ' Runs with ' + str(init_budget) + ' Initial Random Samples')
plt.xlabel('Iterations')
plt.ylabel('Regret' )
#plt.yscale('log')
plt.ylim(0,3.5)    
'''
# Out:
# /tmp/ipykernel_937300/1124206045.py:8: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(sample_numbers, conv_results[0,:,0], style, linewidth=3, label=names2[i], c=colors[i])
# /tmp/ipykernel_937300/1124206045.py:26: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(sample_numbers, Res_dict_raw[method][0,k,:], style, linewidth=3, label=names2[i], c=colors[i], alpha=.5)
# "    \n#sorted_results\nfig = plt.figure(figsize=(12,9))\nfor i, method in enumerate(names):\n    \n    style = '-'\n    sorted_results = Res_dict_raw[method]\n    plt.plot(sample_numbers, -1*sorted_results.squeeze(0).T+best, style, linewidth=3, label=method, c=colors[i])\n    #plt.fill_between(sample_numbers, conv_results[i,:,0]-(1.95*conv_results[i,:,1]/(len(seeds)**0.5)), conv_results[i,:,0]+(1.95*conv_results[i,:,1]/(len(seeds)**0.5)), alpha=0.1, color=colors[i])\n    #plt.title('Convergence Results Across ' + str(len(seeds)) + ' Runs with ' + str(init_budget) + ' Initial Random Samples')\nplt.xlabel('Iterations')\nplt.ylabel('Regret' )\n#plt.yscale('log')\nplt.ylim(0,3.5)    \n"

# %%
Res_dict_raw[method].shape
# Out:
# (1, 5, 91)

# %%
import pandas as pd
import seaborn as sns

end = -1
dmin = 0
dmax = best


sorted_results1 = Res_dict_raw['SAAS']
sorted_results2 = Res_dict_raw['GP_full']
sorted_results3 = Res_dict_raw['GP_PCA']
sorted_results4 = Res_dict_raw['random']







df2 = pd.DataFrame()

d =  pd.DataFrame({'Method':[names2[0]]*len(seeds), 'Final value':(sorted_results1[0,:,end]-dmin)/(dmax-dmin)})
df2 = pd.concat([df2, d])

d =  pd.DataFrame({'Method':[names2[1]]*len(seeds), 'Final value':(sorted_results2[0,:,end]-dmin)/(dmax-dmin)})
df2 = pd.concat([df2, d])

d =  pd.DataFrame({'Method':[names2[2]]*len(seeds), 'Final value':(sorted_results3[0,:,end]-dmin)/(dmax-dmin)})
df2 = pd.concat([df2, d])

d =  pd.DataFrame({'Method':[names2[3]]*len(seeds), 'Final value':(sorted_results4[0,:,end]-dmin)/(dmax-dmin)})
df2 = pd.concat([df2, d])




C = [ sns.color_palette()[0], sns.color_palette()[1],
     sns.color_palette()[2], sns.color_palette()[3], sns.color_palette()[4],
     sns.color_palette()[5], sns.color_palette()[6], sns.color_palette()[7],]
     #sns.color_palette()[8], sns.color_palette()[9], sns.color_palette()[10]]


plt.figure(figsize=(13,9))
for i,ls in enumerate(range(4)):
  plt.axvline(i, color=C[i], linestyle='-', zorder=0)
plt.axhline(1,color='k', linestyle=':',zorder=0)
sns.violinplot(data=df2, x='Method', y='Final value', cut=0, inner="box", scale='width', palette=C, linestyle='dashdot')
#plt.title('Lipophilicity')
plt.xlabel(None)
#plt.ylim(.93,1.001)
#density_norm{“area”, “count”, “width”}
plt.tight_layout()
plt.savefig('./figs/cep/cep_hv_finalVals.png')
# Out:
# /tmp/ipykernel_937300/4063950323.py:45: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.axvline(i, color=C[i], linestyle='-', zorder=0)
